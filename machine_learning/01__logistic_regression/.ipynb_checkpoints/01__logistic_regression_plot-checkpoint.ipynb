# %% [markdown]
# # Plot

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

from scipy.stats import multivariate_normal

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

u_i = 0
sigma = 1.0

x = 0
y = np.arange(-1.0, 1.0, 0.01)
z = (1 / (2*np.pi*sigma**2)**(1/2) ) * np.exp( -(y - u_i)**2 / (2*sigma**2)  )

Axes3D.plot(x, y, z)
# Out:
# ------------------------------------------------------------------------
# AttributeError                         Traceback (most recent call last)
# <ipython-input-13-d44f2e44b320> in <module>()
#       9 z = (1 / (2*np.pi*sigma**2)**(1/2) ) * np.exp( -(y - u_i)**2 / (2*sigma**2)  )
#      10
# ---> 11 Axes3D.plot(x, y, z)
#
# /usr/local/lib/python3.5/dist-packages/mpl_toolkits/mplot3d/axes3d.py in plot(self, xs, ys, *args, **kwargs)
#    1534         :func:`~matplotlib.axes.Axes.plot`
#    1535         '''
# -> 1536         had_data = self.has_data()
#    1537
#    1538         # `zs` can be passed positionally or as keyword; checking whether
#
# AttributeError: 'numpy.ndarray' object has no attribute 'has_data'
