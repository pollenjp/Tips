# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#jupyter_tips" data-toc-modified-id="jupyter_tips-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>jupyter_tips</a></span><ul class="toc-item"><li><span><a href="#vim-on-jupyter" data-toc-modified-id="vim-on-jupyter-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>vim on jupyter</a></span></li><li><span><a href="#show-mnist-image" data-toc-modified-id="show-mnist-image-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>show mnist image</a></span></li><li><span><a href="#fig,-ax" data-toc-modified-id="fig,-ax-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>fig, ax</a></span></li></ul></li></ul></div>

# %% [markdown]
# # jupyter_tips

# %% [markdown]
# ## vim on jupyter
# - <a href="https://github.com/lambdalisue/jupyter-vim-binding">jupyter-vim-binding</a>

# %% [markdown]
# ## show mnist image
# - <a href="https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.imshow.html">matplotlib.axes.Axes.imshow</a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

fig = plt.figure(figsize=(9, 15))
fig.subplots_adjust(left=0, right=1, bottom=0, top=0.5,
                    hspace=0.05, wspace=0.05)

# show label above each mnist's image
for i in range(9):
    ax = fig.add_subplot(1, 9, i + 1, xticks = [], yticks = [])
    ax.set_title(str(y_train[i]))
    ax.imshow(x_train[i], cmap='gray')

# %% [markdown]
# ## fig, ax

# %%
def sigmoid(x):
    return 1 / (1+np.exp(-x))

def relu(x):
    return np.maximum(0, x)

def tanh(x):
    return np.tanh(x)

fig = plt.figure()
x = np.linspace(-10, 10, 1000)

ax = fig.add_subplot(111)
ax.plot(x, sigmoid(x), label='sigmoid')
ax.plot(x, relu(x), label='ReLU')
ax.plot(x, tanh(x), label='tanh')

plt.legend()
plt.xlim(-5, 5)
plt.ylim(-1.1, 2)
plt.grid(which='major',color='gray',linestyle='-')
plt.show()

# %%
fig = plt.figure()
x = np.linspace(-10, 10, 1000)

ax = fig.add_subplot(221)
ax.plot(x, sigmoid(x), label='sigmoid')
plt.legend()
plt.xlim(-5, 5)
plt.ylim(-1.1, 2)
plt.grid(which='major',color='gray',linestyle='-')

ax = fig.add_subplot(222)
ax.plot(x, relu(x), label='ReLU')
plt.legend()
plt.xlim(-5, 5)
plt.ylim(-1.1, 2)
plt.grid(which='major',color='gray',linestyle='-')

ax = fig.add_subplot(223)
ax.plot(x, tanh(x), label='tanh')
plt.legend()
plt.xlim(-5, 5)
plt.ylim(-1.1, 2)
plt.grid(which='major',color='gray',linestyle='-')

plt.show()
